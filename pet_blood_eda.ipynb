# %%
import pandas as pd

# %%
df = pd.read_csv('new_df2.csv')

# %%
df.shape
# Out:
# (12258, 43)

# %%
df.groupby(['진단코드']).mean()[20:30]
# Out:
#              %LYM        HCT        WBC         PLT        HGB       RBC  \
# 진단코드
# 2006    27.500000  46.300000  10.580000  612.000000  15.500000  6.890000
# 2007    27.300000  39.844444  13.596667  330.666667  13.888889  5.826667
# 2008    13.900000  41.700000   9.500000  763.000000  14.800000  6.950000
# 2009    10.000000  41.700000  16.000000  202.000000  14.500000  6.280000
# 2011의심  15.200000  49.900000        NaN  269.000000  16.500000  6.850000
# 2012     2.900000  41.300000  11.800000  264.000000  12.700000  4.770000
# 2013    12.100000  46.100000        NaN  486.833333  15.700000  6.630000
# 2014    21.727000  43.390000  12.954762  449.633333  14.826667  6.722692
# 2014.0  19.666667  45.866667        NaN  180.000000  18.000000  6.873333
# 2015    31.900000  52.200000   5.200000  352.000000  19.500000       NaN
#
#               MCV       MCHC        MCH        RDW  ...     %BASO  #BASO  \
# 진단코드                                                ...
# ...
