# %%
import pandas as pd
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
df = pd.read_csv('result/new1_df02.csv')
df
# Out:
#        보호자명     환자명          생일         검사일 병원  %LYM   HCT   WBC     PLT  \
# 0       김용모    까미dr  2002-07-10  2018-08-23  A  23.1  40.7   NaN   525.0
# 1       문성환     또띠r  2002-04-23  2018-01-15  A  42.4  46.0  21.8   300.0
# 2       이승연     아지r  2000-09-04  2017-03-13  A  18.5  37.8   NaN   550.0
# 3      임순미R      비코  2000-11-17  2017-02-08  A  19.5  47.2   NaN   799.0
# 4       김하나    체리br  2002-05-07  2017-05-19  A   6.5  44.7  26.9  1187.0
# ...     ...     ...         ...         ... ..   ...   ...   ...     ...
# 12254   김영진   보름(R)  2018-12-18  2019-03-21  G  21.2  40.3  11.3   480.0
# 12255   이상미      삐삐  2008-03-24  2019-03-27  G  13.5  38.8   3.5   343.0
# 12256   하지윤   짱구(R)  2008-03-26  2019-03-26  G  21.6  21.9   NaN   466.0
# 12257   이정애     깨돌이  2005-09-27  2019-03-29  G  19.2  46.0   6.7   605.0
# 12258   남기현  초롱이(R)  2003-03-28  2019-03-28  G  27.7  34.8  23.8   554.0
#
#         HGB  ...  #BASO  CHCM_a  CH_a  HDW_a  LUC(%)_a  LUC(#)_a  LI_a  \
# ...

# %%
# df = pd.read_csv('result/new_df2.csv')
# df
# Out:
#        보호자명     환자명          생일         검사일 병원  %LYM   HCT   WBC     PLT  \
# 0       김용모    까미dr  2002-07-10  2018-08-23  A  23.1  40.7   NaN   525.0
# 1       문성환     또띠r  2002-04-23  2018-01-15  A  42.4  46.0  21.8   300.0
# 2       이승연     아지r  2000-09-04  2017-03-13  A  18.5  37.8   NaN   550.0
# 3      임순미R      비코  2000-11-17  2017-02-08  A  19.5  47.2   NaN   799.0
# 4       김하나    체리br  2002-05-07  2017-05-19  A   6.5  44.7  26.9  1187.0
# ...     ...     ...         ...         ... ..   ...   ...   ...     ...
# 12254   김영진   보름(R)  2018-12-18  2019-03-21  G  21.2  40.3  11.3   480.0
# 12255   이상미      삐삐  2008-03-24  2019-03-27  G  13.5  38.8   3.5   343.0
# 12256   하지윤   짱구(R)  2008-03-26  2019-03-26  G  21.6  21.9   NaN   466.0
# 12257   이정애     깨돌이  2005-09-27  2019-03-29  G  19.2  46.0   6.7   605.0
# 12258   남기현  초롱이(R)  2003-03-28  2019-03-28  G  27.7  34.8  23.8   554.0
#
#         HGB  ...  #BASO  CHCM_a  CH_a  HDW_a  LUC(%)_a  LUC(#)_a  LI_a  \
# ...

# %%
from sklearn.decomposition import PCA

# %%
df.columns
# Out:
# Index(['%LYM', 'HCT', 'WBC', 'PLT', 'HGB', 'RBC', 'MCV', 'MCHC', 'MCH', 'RDW',
#        'MPV', '#LYM', '#GRA', '#EOS', '%GRA', '%MON', '#MON', '%EOS', 'PDW',
#        'PCT', 'RDW2', '%OTHR(W-MCR)', '#OTHR(W-MCC)', 'RDW-SD', 'P-LCR',
#        '%NEU', '#NEU', '%BASO', '#BASO', 'HDW_a', 'CH_a', 'CHCM_a', 'LUC(%)_a',
#        'LUC(#)_a', 'LI_a', '#RETIC', '%RETIC', 'label'],
#       dtype='object')

# %%
# import pandas as pd
# url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
# # load dataset into Pandas DataFrame
# df = pd.read_csv(url, names=['sepal length','sepal width','petal length','petal width','target'])

# %%
df1 = df[['%LYM', 'HCT', 'WBC', 'PLT', 'HGB',
       'RBC', 'MCV', 'MCHC', 'MCH', 'RDW', 'MPV', '#LYM', '#GRA', '#EOS',
       '%GRA', '%MON', '#MON', '%EOS', 'PDW', 'PCT', 'RDW2', '%OTHR(W-MCR)',
       '#OTHR(W-MCC)', 'RDW-SD', 'P-LCR', '%NEU', '#NEU', '%BASO', '#BASO',
       'HDW_a', 'CH_a', 'CHCM_a', 'LUC(%)_a', 'LUC(#)_a', 'LI_a', '#RETIC',
       '%RETIC']]

# %%
df1 = df1.astype('float32')
df1
# Out:
#             %LYM        HCT        WBC     PLT        HGB   RBC        MCV  \
# 0      23.100000  40.700001        NaN   525.0  18.900000  5.83  69.800003
# 1      42.400002  46.000000  21.799999   300.0  15.300000  6.27  73.400002
# 2      18.500000  37.799999        NaN   550.0  14.900000  5.40  70.000000
# 3      19.500000  47.200001        NaN   799.0  16.799999  6.41  73.599998
# 4       6.500000  44.700001  26.900000  1187.0  12.200000  6.34  70.500000
# ...          ...        ...        ...     ...        ...   ...        ...
# 12254  21.200001  40.299999  11.300000   480.0  15.100000  5.36  75.199997
# 12255  13.500000  38.799999   3.500000   343.0  14.200000   NaN  80.300003
# 12256  21.600000  21.900000        NaN   466.0   7.800000  3.08  71.099998
# 12257  19.200001  46.000000   6.700000   605.0  17.299999   NaN  76.900002
# 12258  27.700001  34.799999  23.799999   554.0  12.600000  4.59  75.800003
#
# ...

# %%
corr = df1.corr(method='pearson')
# corr
fig, ax = plt.subplots(figsize=(20,20))
sns.heatmap(corr, annot=True, cmap='RdYlGn', linewidths=.5)

# %%
df2 = df1[["MCV", 'CH_a']]

# %%
fig = plt.figure(figsize=(15,15))
plt.scatter(df2["MCV"], df2['CH_a'])

# %%
# fig = plt.figure(figsize=(15,15))
# plt.scatter(df1["MCH"], df1['CH_a'])

# %%
f,ax=plt.subplots(1,3,figsize=(20,8))
# plt.scatter(df1["MCH"], df1['CH_a'])
ax[0].scatter(df1["MCH"], df1['CH_a'])
ax[1].scatter(df1["%GRA"], df1['%LYM'])
ax[2].scatter(df1["MCV"], df1['CH_a'])

# %%
from sklearn.cluster import KMeans
import sklearn.metrics as sm

# %%
col_list = ['%LYM', 'HCT', 'WBC', 'PLT', 'HGB',
       'RBC', 'MCV', 'MCHC', 'MCH', 'RDW', 'MPV', '#LYM', '#GRA', '#EOS',
       '%GRA', '%MON', '#MON', '%EOS', 'PDW', 'PCT', 'RDW2', '%OTHR(W-MCR)',
       '#OTHR(W-MCC)', 'RDW-SD', 'P-LCR', '%NEU', '#NEU', '%BASO', '#BASO',
       'HDW_a', 'CH_a', 'CHCM_a', 'LUC(%)_a', 'LUC(#)_a', 'LI_a', '#RETIC',
       '%RETIC']

# %%
df['진단코드'].value_counts()[0:50]
# Out:
# X         513
# 2043      353
# 2046      311
# 2082      272
# 중성화수술     267
# x         257
# 2087      234
# 2001      228
# 2101      178
# 2170      147
# 2092      134
# 2116      121
# -          99
# 2275       91
# 2133       83
# 건강검진       75
# 2091       74
# 2031       74
# 2095       74
# 2185       73
# 2048       72
# 2071       72
# 2274       67
# 2181       65
# 중성화        60
# 2236       59
# 2126       58
# 2002       58
# 2244       57
# 2020       55
# 2273       55
# 2255       54
# 2022       51
# 2259       48
# 2267       48
# 2049       46
# 2120       45
# 2228       45
# 2021       45
# 2245       45
# 2071.0     42
# 2073       42
# 슬개골탈구      40
# 2084       39
# 2283       37
# 2193       36
# 2081       35
# 2119       34
# 2257       33
# 2171       33
# Name: 진단코드, dtype: int64

# %%
df2 = df1.fillna(0)
X=df2[col_list].values
model = KMeans(n_clusters=30)
model.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=30, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
colormap = np.array(['pink','purple'])
plt.scatter(df2['WBC'], df2['HCT'])
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
x = StandardScaler().fit_transform(df1)
print(x)
# Out:
# [[-0.11146147 -0.29909307         nan ...         nan         nan
#           nan]
#  [ 1.1579479   0.2312419   0.66030085 ...         nan         nan
#           nan]
#  [-0.414015   -0.5892765          nan ...         nan         nan
#           nan]
#  ...
#  [-0.21012023 -2.1802814          nan ...         nan         nan
#           nan]
#  [-0.36797422  0.2312419  -0.6661064  ...         nan         nan
#           nan]
#  [ 0.19109206 -0.88946617  0.8359839  ...         nan         nan
#           nan]]

# %%
# print('NumPy covariance matrix: \n%s' %np.cov(x.T))
# Out:
# NumPy covariance matrix:
# [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]

# %%
from sklearn.decomposition import PCA
pca = PCA().fit(df2)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.show()

# %%
# df2.fillna('0',inplace=True)
df2 = df2[['%LYM', 'HCT', 'WBC', 'PLT', 'HGB',
       'RBC', 'MCV', 'MCHC', 'MCH', 'RDW']]
corr = df2.corr(method='pearson')
# print(corr)
sns.heatmap(df2.corr(), annot=True, cmap='RdYlGn', linewidths=0.5)

# %%
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width       target
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
from sklearn.preprocessing import StandardScaler
features = ['sepal length', 'sepal width', 'petal length', 'petal width']

# %%
# Separating out the features
x = df.loc[:, features].values

# %%
df1 = pd.DataFrame(x).T

# %%
corr = df.corr(method='pearson')
print(corr)
# Out:
#               sepal length  sepal width  petal length  petal width
# sepal length      1.000000    -0.109369      0.871754     0.817954
# sepal width      -0.109369     1.000000     -0.420516    -0.356544
# petal length      0.871754    -0.420516      1.000000     0.962757
# petal width       0.817954    -0.356544      0.962757     1.000000

# %%
# Separating out the target
y = df.loc[:,['target']].values

# %%
# Standardizing the features
x = StandardScaler().fit_transform(x)

# %%
# x

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)

principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])

# %%
finalDf = pd.concat([principalDf, df[['target']]], axis = 1)

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
colors = ['r', 'g', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['target'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()
